# %%
df = pd.read_csv("../data/processed/netflix_cleaned_featured.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("../data/processed/netflix_cleaned_featured.csv")
#
# NameError: name 'pd' is not defined
